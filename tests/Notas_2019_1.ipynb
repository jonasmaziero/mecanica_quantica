# %% [markdown]
# #### Notas de aula: Mecânica Quântica, Autor: Jonas Maziero, Departamento de Física, UFSM

# %%
# %run /Users/jonasmaziero/Dropbox/GitHub/mecanica_quantica/init.ipynb

# %%
Notas, Nome, P1, P2, Np, E, Nf = symbols("Notas, Nome, P1, P2, Np, E, Nf")
Andre,Arthur,Augusto,Claudia,Cristiane,Dyllan,Luis,Matheus,Roberta,Vitor = symbols("Andre,Arthur,Augusto,Claudia,Cristiane,Dyllan,Luis,Matheus,Roberta,Vitor")
Notas = Matrix([[Nome, P1, P2, Np, E, Nf],
                [Andre, 5.00, 3.50, 4.25, 5.75, 5.00], 
                [Arthur, 8.75, 2.50, 5.63, 7.00, 6.31],
                [Augusto, 9.50, 7.50, 8.50, 0.00, 8.50],
                [Claudia, 0.50, 0.00, 0.25, 0.00, 0.13],
                [Cristiane, 5.25, 0.00, 2.63, 0.00, 1.32],
                [Dyllan, 3.50, 2.00, 2.75, 4.00, 3.38],
                [Luis, 7.25, 6.00, 6.63, 5.00, 5.81],
                [Matheus, 2.50, 2.50, 2.50, 4.50, 3.50],
                [Roberta, 0.50, 0.00, 0.25, 0.00, 0.13],
                [Vitor, 0.50, 1.50, 1.00, 1.50, 1.25]])
Notas
# Out:
# ⎡  Nome      P₁   P₂    Np    E     Nf ⎤
# ⎢                                      ⎥
# ⎢  Andre    5.0   3.5  4.25  5.75  5.0 ⎥
# ⎢                                      ⎥
# ⎢ Arthur    8.75  2.5  5.63  7.0   6.31⎥
# ⎢                                      ⎥
# ⎢ Augusto   9.5   7.5  8.5   0.0   8.5 ⎥
# ⎢                                      ⎥
# ⎢ Claudia   0.5   0.0  0.25  0.0   0.13⎥
# ⎢                                      ⎥
# ⎢Cristiane  5.25  0.0  2.63  0.0   1.32⎥
# ⎢                                      ⎥
# ⎢ Dyllan    3.5   2.0  2.75  4.0   3.38⎥
# ⎢                                      ⎥
# ⎢  Luis     7.25  6.0  6.63  5.0   5.81⎥
# ⎢                                      ⎥
# ⎢ Matheus   2.5   2.5  2.5   4.5   3.5 ⎥
# ⎢                                      ⎥
# ⎢ Roberta   0.5   0.0  0.25  0.0   0.13⎥
# ⎢                                      ⎥
# ⎣  Vitor    0.5   1.5  1.0   1.5   1.25⎦

# %%
(2.75+4)/2
# Out:
# 3.375
