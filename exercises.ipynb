# %% [markdown]
# UFSM: 2018/1; Notas de aula: Mecânica Quântica; Autor: Jonas Maziero

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## Probabilidades

# %% [markdown]
# ## Postulados

# %% [markdown]
# ## Representações da dinâmica

# %% [markdown]
# ## Spin 1/2

# %% [markdown]
# ## Maser

# %% [markdown]
# ## Relações de incerteza

# %% [markdown]
# ## Operador densidade

# %% [markdown]
# ## Desigualdades de Bell

# %% [markdown]
# ## MQ na base de posição

# %% [markdown]
# ## MQ na base de momento linear

# %% [markdown]
# ## Momento angular

# %% [markdown]
# ## Adição de momento angular

# %% [markdown]
# ## Aproximações independentes do tempo

# %% [markdown]
# ## Aproximações dependentes do tempo

# %% [markdown]
# ## MQ relativística

# %% [markdown]
# ## Teoria quântica do espalhamento
