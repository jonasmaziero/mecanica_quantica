# %% [markdown]
# ### Notas de aula: Mecânica Quântica <br> Autor: Jonas Maziero

# %% [markdown]
# # Potencial Barreira
# Para a barreira de potencial, podemos escrever a função energia potencial como:
# \begin{cases}
# U(x<0)=0, \\
# U(0<x<a)=U_{0}=\text{constante}, \\
# U(x>a)=0.
# \end{cases}
# As soluções da equação de Schrödinher, que, para as três regiões, pode ser escrita na forma
# \begin{equation}
# \partial_{xx}\Xi(x)+k^{2}\Xi(x)=0,
# \end{equation}
# são obtidas como no caso do potencial dregrau.
#
# ## $E<U_{0}$
# Nesse caso as soluções da EqSIT1D podem ser escritas na forma
# \begin{cases}
# \Xi_{e}(x<0) = c_{ed}e^{ik_{e}x} + c_{ee}e^{-ik_{e}x}, \\
# \Xi_{b}(0<x<a) = c_{bd}e^{-k_{b}x} + c_{bc}e^{k_{b}x}, \\
# \Xi_{d}(x>a) = c_{dd}e^{ik_{e}x} + c_{de}e^{-ik_{e}x},
# \end{cases}
# com
# \begin{equation}
# k_{e}=\frac{\sqrt{2mE}}{\hbar} \text{ e } k_{b}=\frac{\sqrt{2m(U_{0}-E)}}{\hbar}.
# \end{equation}
# Assim
# \begin{equation}
# \frac{k_{b}}{k_{e}} = \frac{\sqrt{2m(U_{0}-E)}}{\sqrt{2mE}} \therefore k_{b} = k_{e}\sqrt{\frac{U_{0}}{E}-1}.
# \end{equation}
# OBS. Aqui não usarei o til para diferenciar os dois casos.
#
# Novamente, $c_{ed}$ determina o fluxo de quantons incidindo na barreira de potencial e consideramos que os quantons movem-se inicialmente na região $x<0$ da esquerda para a direita. Pontanto, se o quanton passou para a região $x>a$ não há motivo para este retornar, então
# \begin{equation}
# c_{de} := 0.
# \end{equation}

# %% [markdown]
# As outras constantes, $c_{ee},c_{bd},c_{ba},c_{dd}$, são determinadas, em termos de $c_{ed}$, impondo a continuidade da função de onda e de sua primeira derivada. Usando
# \begin{cases}
# \partial_{x}\Xi_{e} = ik_{e}\left(c_{ed}e^{ik_{e}x}-c_{ee}e^{-ik_{e}x}\right), \\
# \partial_{x}\Xi_{b} = -k_{b}\left(c_{bd}e^{-k_{b}x}-c_{bc}e^{k_{b}x}\right), \\
# \partial_{x}\Xi_{d} = ik_{e}c_{dd}e^{ik_{e}x},
# \end{cases}
# teremos
# \begin{align}
# \Xi_{e}(x=0) = \Xi_{b}(x=0) & \\
# & \therefore c_{ed}+c_{ee}=c_{bd}+c_{bc} \therefore -c_{ee}+c_{bd}+c_{bc}+0c_{dd}=c_{ed}, \\
# \Xi_{b}(x=a) = \Xi_{d}(x=a) & \\
# & \therefore c_{bd}e^{-k_{b}a}+c_{bc}e^{k_{b}a}=c_{dd}e^{ik_{e}a} \therefore 0c_{ee}+e^{-k_{b}a}c_{bd}+e^{k_{b}a}c_{bc}-e^{ik_{e}a}c_{dd}=0, \\
# \partial_{x}\Xi_{e}(x=0)=\partial_{x}\Xi_{b}(x=0) & \\
# & \therefore ik_{e}(c_{ed}-c_{ee})=-k_{b}(c_{bd}-c_{bc}) \therefore ik_{e}c_{ee}-k_{b}c_{bd}+k_{b}c_{bc}+0c_{dd}=ik_{e}c_{ed}, \\
# \partial_{x}\Xi_{e}(x=a)=\partial_{x}\Xi_{b}(x=a) & \\
# & \therefore -k_{b}\left(c_{bd}e^{-k_{b}a}-c_{bc}e^{k_{b}a}\right) = ik_{e}c_{dd}e^{ik_{e}a} \therefore 0c_{ee}-k_{b}e^{-k_{b}a}c_{bd}+k_{b}e^{k_{b}a}c_{bc}-ik_{e}e^{ik_{e}a}c_{dd}=0.
# \end{align}
# Este sistema de equações lineares (SEL) está resolvido com o código Sympy abaixo.

# %%
from sympy import init_printing, symbols, solve, exp
init_printing(use_unicode=True)

# %%
ced,cee,cbd,cbc,cdd=symbols('c_{ed},c_{ee},c_{bd},c_{bc},c_{dd}')
a,ke,kb = symbols('a,k_{e},k_{b}')
solve([ced+cee-cbd-cbc, 
       cbd*exp(-kb*a)+cbc*exp(kb*a)-cdd*exp(1j*ke*a), 
      1j*ke*(ced-cee)+kb*(cbd-cbc), 
       -kb*(cbd*exp(-kb*a)-cbc*exp(kb*a))-1j*ke*cdd*exp(1j*ke*a)],
      [ced,cee,cbd,cbc])
# Out:
# ⎧                                                              -a⋅k_{b}  ⅈ⋅a⋅k
# ⎪                    -a⋅k_{b}  ⅈ⋅a⋅k_{e}   0.5⋅ⅈ⋅c_{dd}⋅k_{e}⋅ℯ        ⋅ℯ
# ⎨c_{bc}: 0.5⋅c_{dd}⋅ℯ        ⋅ℯ          + ───────────────────────────────────
# ⎪                                                           k_{b}
# ⎩
#
# _{e}                                                               a⋅k_{b}  ⅈ⋅
#                           a⋅k_{b}  ⅈ⋅a⋅k_{e}   0.5⋅ⅈ⋅c_{dd}⋅k_{e}⋅ℯ       ⋅ℯ
# ────, c_{bd}: 0.5⋅c_{dd}⋅ℯ       ⋅ℯ          - ───────────────────────────────
#                                                                k_{b}
#
#
# a⋅k_{e}                               a⋅k_{b}  ⅈ⋅a⋅k_{e}
#                  0.25⋅ⅈ⋅c_{dd}⋅k_{b}⋅ℯ       ⋅ℯ            0.25⋅ⅈ⋅c_{dd}⋅k_{b}
# ───────, c_{ed}: ─────────────────────────────────────── - ───────────────────
#                                   k_{e}                                     k_
#
#
#   -a⋅k_{b}  ⅈ⋅a⋅k_{e}
# ⋅ℯ        ⋅ℯ                        a⋅k_{b}  ⅈ⋅a⋅k_{e}               -a⋅k_{b}
# ───────────────────── + 0.5⋅c_{dd}⋅ℯ       ⋅ℯ          + 0.5⋅c_{dd}⋅ℯ        ⋅
# {e}
#
#
#                                   a⋅k_{b}  ⅈ⋅a⋅k_{e}                        -a
#  ⅈ⋅a⋅k_{e}   0.25⋅ⅈ⋅c_{dd}⋅k_{e}⋅ℯ       ⋅ℯ            0.25⋅ⅈ⋅c_{dd}⋅k_{e}⋅ℯ
# ℯ          - ─────────────────────────────────────── + ───────────────────────
#                               k_{b}                                     k_{b}
#
#
# ⋅k_{b}  ⅈ⋅a⋅k_{e}                                 a⋅k_{b}  ⅈ⋅a⋅k_{e}
#       ⋅ℯ                     0.25⋅ⅈ⋅c_{dd}⋅k_{b}⋅ℯ       ⋅ℯ            0.25⋅ⅈ⋅
# ─────────────────, c_{ee}: - ─────────────────────────────────────── + ───────
#                                               k_{e}
#
#
#               -a⋅k_{b}  ⅈ⋅a⋅k_{e}                        a⋅k_{b}  ⅈ⋅a⋅k_{e}
# c_{dd}⋅k_{b}⋅ℯ        ⋅ℯ            0.25⋅ⅈ⋅c_{dd}⋅k_{e}⋅ℯ       ⋅ℯ
# ───────────────────────────────── - ─────────────────────────────────────── +
#           k_{e}                                      k_{b}
#
#
#                      -a⋅k_{b}  ⅈ⋅a⋅k_{e}⎫
# 0.25⋅ⅈ⋅c_{dd}⋅k_{e}⋅ℯ        ⋅ℯ         ⎪
# ────────────────────────────────────────⎬
#                  k_{b}                  ⎪
#                                         ⎭

# %% [markdown]
# Assim
# \begin{align}
# c_{bc} &= \frac{c_{dd}e^{-ak_{b}+iak_{e}}}{2}\left(\frac{k_{b}+ik_{e}}{k_{b}}\right), \\
# c_{bd} &= \frac{c_{dd}e^{ak_{b}+iak_{e}}}{2}\left(\frac{k_{b}-ik_{e}}{k_{b}}\right), \\
# c_{ed} &= \frac{c_{dd}e^{iak_{e}}}{2}\left(2\cosh(ak_{b})+i\frac{k_{b}^{2}-k_{e}^{2}}{k_{b}k_{e}}\sinh(ak_{b})\right), \\
# c_{ee} &= -\frac{ic_{dd}e^{iak_{e}}}{2}\frac{k_{b}^{2}+k_{e}^{2}}{k_{b}k_{e}}\sinh(ak_{b}).
# \end{align}
#
# Na forma matricial, o SEL acima fica escrito como segue:
# \begin{equation}
# \begin{bmatrix} -1&1&1&0 \\ 0&e^{-k_{b}a}&e^{k_{b}a}&-e^{ik_{e}a} \\ ik_{e}&-k_{b}&k_{b}&0 \\ 0&-k_{b}e^{-k_{b}a}&k_{b}e^{k_{b}a}&-ik_{e}e^{ik_{e}a} \end{bmatrix}\begin{bmatrix} c_{ee}\\c_{bd}\\c_{bc}\\c_{dd}\end{bmatrix}=\begin{bmatrix} c_{ed} \\ 0 \\ ik_{e}c_{ed} \\ 0\end{bmatrix}\text{ ou } A|x\rangle=|y\rangle.
# \end{equation}
# Se $\det(A)\ne 0$, a inversa de $A$ existe e a solução desse sistema de equações lineares não homogêneo é
# \begin{equation}
# |x\rangle=A^{-1}|y\rangle \text{, com } (A^{-1})_{j,k}=\frac{(-1)^{k+j}\det(A^{(k,j)})}{\det(A)}.
# \end{equation}
# No entanto, essas contas são muito longas para os propósitos dessa disciplina, e por isso usaremos os resultados obtidos com o Sympy, como mostrado abaixo.

# %%
from sympy import Matrix, simplify

# %%
A = Matrix([[-1,1,1,0],[0,exp(-kb*a),exp(kb*a),-exp(1j*ke*a)],[1j*ke,-kb,kb,0],
            [0,-kb*exp(-kb*a),kb*exp(kb*a),-1j*ke*exp(1j*ke*a)]]); A
# Out:
# ⎡    -1              1                1                      0             ⎤
# ⎢                                                                          ⎥
# ⎢                 -a⋅k_{b}          a⋅k_{b}             1.0⋅ⅈ⋅a⋅k_{e}      ⎥
# ⎢     0          ℯ                 ℯ                  -ℯ                   ⎥
# ⎢                                                                          ⎥
# ⎢1.0⋅ⅈ⋅k_{e}       -k_{b}           k_{b}                    0             ⎥
# ⎢                                                                          ⎥
# ⎢                     -a⋅k_{b}         a⋅k_{b}                1.0⋅ⅈ⋅a⋅k_{e}⎥
# ⎣     0       -k_{b}⋅ℯ          k_{b}⋅ℯ         -1.0⋅ⅈ⋅k_{e}⋅ℯ             ⎦

# %%
Am1 = A.inv()#; simplify(Am1) # is not working anymore

# %%
cee = Am1[0,0]*ced + 0 + Am1[0,2]*1j*ke*ced + 0; simplify(cee)
# Out:
#        ⎛        ⎛       5              4                   3      2
# c_{ed}⋅⎝- k_{b}⋅⎝- k_{b}  - 5.0⋅ⅈ⋅k_{b} ⋅k_{e} + 10.0⋅k_{b} ⋅k_{e}  + 10.0⋅ⅈ⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2      3                  4          5         ⎛             4
# _{b} ⋅k_{e}  - 5.0⋅k_{b}⋅k_{e}  - ⅈ⋅k_{e}  + k_{e}⋅⎝- 2.0⋅ⅈ⋅k_{b}  + 4.0⋅k_{b}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 3                        3              4⎞  2⋅a⋅k_{b}   ⎛       5  4⋅a⋅k_{b}
#  ⋅k_{e} + 4.0⋅k_{b}⋅k_{e}  + 2.0⋅ⅈ⋅k_{e} ⎠⋅ℯ          + ⎝- k_{b} ⋅ℯ          +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           5              4        4⋅a⋅k_{b}              4        2⋅a⋅k_{b}
#  2.0⋅k_{b}  + 5.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 2.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           3      2  4⋅a⋅k_{b}            3      2  2⋅a⋅k_{b}            3
# 10.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 4.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 4.0⋅k_{b} ⋅k_{e
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2               2      3  4⋅a⋅k_{b}                  4  4⋅a⋅k_{b}
# }  - 10.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 5.0⋅k_{b}⋅k_{e} ⋅ℯ          + 4.0⋅k_{b}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       4  2⋅a⋅k_{b}                  4              5  4⋅a⋅k_{b}              5
# ⋅k_{e} ⋅ℯ          + 2.0⋅k_{b}⋅k_{e}  + 1.0⋅ⅈ⋅k_{e} ⋅ℯ          - 2.0⋅ⅈ⋅k_{e}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2⋅a⋅k_{b}⎞  4⋅a⋅k_{b}⎞ ⎛       9              8                   7      2
# ⋅ℯ         ⎠⋅ℯ         ⎠⋅⎝- k_{b}  - 9.0⋅ⅈ⋅k_{b} ⋅k_{e} + 36.0⋅k_{b} ⋅k_{e}  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#              6      3              5      4                4      5
#  84.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 126.0⋅k_{b} ⋅k_{e}  - 126.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 84.0⋅k_{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   3      6               2      7                  8          9         ⎛
# b} ⋅k_{e}  + 36.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 9.0⋅k_{b}⋅k_{e}  - ⅈ⋅k_{e}  + k_{e}⋅⎝- 6.0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         8             7                     6      2             5      3
# ⋅ⅈ⋅k_{b}  + 36.0⋅k_{b} ⋅k_{e} + 84.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 84.0⋅k_{b} ⋅k_{e}  - 84
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         3      5               2      6                   7              8⎞  2
# .0⋅k_{b} ⋅k_{e}  - 84.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 36.0⋅k_{b}⋅k_{e}  + 6.0⋅ⅈ⋅k_{e} ⎠⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ⋅a⋅k_{b}   ⎛         9              8                   7      2
#          + ⎝3.0⋅k_{b}  + 9.0⋅ⅈ⋅k_{b} ⋅k_{e} + 12.0⋅k_{b} ⋅k_{e}  + 60.0⋅ⅈ⋅k_{b
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  6      3             5      4               4      5             3      6
# } ⋅k_{e}  - 30.0⋅k_{b} ⋅k_{e}  + 78.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 84.0⋅k_{b} ⋅k_{e}  + 1
# ──────────────────────────────────────────────────────────────────────────────
#                      ⎛       6              5                   4      2
#                      ⎝- k_{b}  - 6.0⋅ⅈ⋅k_{b} ⋅k_{e} + 15.0⋅k_{b} ⋅k_{e}  + 20.
#
#            2      7                   8               9⎞  4⋅a⋅k_{b}   ⎛
# 2.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 45.0⋅k_{b}⋅k_{e}  - 15.0⋅ⅈ⋅k_{e} ⎠⋅ℯ          + ⎝1.0⋅k_{
# ──────────────────────────────────────────────────────────────────────────────
#          3      3             2      4                    5            6
# 0⋅ⅈ⋅k_{b} ⋅k_{e}  - 15.0⋅k_{b} ⋅k_{e}  - 6.0⋅ⅈ⋅k_{b}⋅k_{e}  + 1.0⋅k_{e}  + k_{
#
#   9  6⋅a⋅k_{b}            9  2⋅a⋅k_{b}              8        6⋅a⋅k_{b}
# b} ⋅ℯ          - 3.0⋅k_{b} ⋅ℯ          - 9.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          - 6.0⋅ⅈ
# ──────────────────────────────────────────────────────────────────────────────
#    ⎛             5             4                    3      2            2
# e}⋅⎝- 4.0⋅ⅈ⋅k_{b}  + 12.0⋅k_{b} ⋅k_{e} + 8.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 8.0⋅k_{b} ⋅k_{e
#
#       8        4⋅a⋅k_{b}              8        2⋅a⋅k_{b}               8
# ⋅k_{b} ⋅k_{e}⋅ℯ          + 9.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 12.0⋅ⅈ⋅k_{b} ⋅k_{e}
# ──────────────────────────────────────────────────────────────────────────────
#  3                     4            5⎞  2⋅a⋅k_{b}   ⎛       6  4⋅a⋅k_{b}
# }  + 12.0⋅ⅈ⋅k_{b}⋅k_{e}  - 4.0⋅k_{e} ⎠⋅ℯ          + ⎝- k_{b} ⋅ℯ          + 2.0
#
#              7      2  6⋅a⋅k_{b}             7      2  4⋅a⋅k_{b}             7
#  - 36.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 36.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 12.0⋅k_{b}
# ──────────────────────────────────────────────────────────────────────────────
#       6              5        4⋅a⋅k_{b}              5        2⋅a⋅k_{b}
# ⋅k_{b}  + 6.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 4.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 15.0
#
#       2  2⋅a⋅k_{b}               6      3  6⋅a⋅k_{b}               6      3  4
# ⋅k_{e} ⋅ℯ          + 84.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 84.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#       4      2  4⋅a⋅k_{b}             4      2  2⋅a⋅k_{b}             4      2
# ⋅k_{b} ⋅k_{e} ⋅ℯ          + 12.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 10.0⋅k_{b} ⋅k_{e}
#
# ⋅a⋅k_{b}               6      3  2⋅a⋅k_{b}               6      3
#          + 60.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 56.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 126.0⋅k_{b
# ──────────────────────────────────────────────────────────────────────────────
#                3      3  4⋅a⋅k_{b}              3      3  2⋅a⋅k_{b}
#  - 20.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 8.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 15.0⋅k_{
#
#  5      4  6⋅a⋅k_{b}             5      4  4⋅a⋅k_{b}             5      4  2⋅a
# } ⋅k_{e} ⋅ℯ          + 84.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 30.0⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#   2      4  4⋅a⋅k_{b}            2      4  2⋅a⋅k_{b}             2      4
# b} ⋅k_{e} ⋅ℯ          + 8.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 14.0⋅k_{b} ⋅k_{e}  + 6.
#
# ⋅k_{b}                4      5  6⋅a⋅k_{b}               4      5  2⋅a⋅k_{b}
#        - 126.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 78.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          +
# ──────────────────────────────────────────────────────────────────────────────
#                5  4⋅a⋅k_{b}                     5  2⋅a⋅k_{b}            6  4⋅a
# 0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          - 12.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          + 1.0⋅k_{e} ⋅ℯ
#
#             4      5             3      6  6⋅a⋅k_{b}             3      6  4⋅a
# 96.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 84.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 84.0⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
# ⋅k_{b}            6  2⋅a⋅k_{b}            6⎞  4⋅a⋅k_{b}⎞ ⎛       9
#        - 4.0⋅k_{e} ⋅ℯ          + 6.0⋅k_{e} ⎠⋅ℯ         ⎠⋅⎝- k_{b}  - 9.0⋅ⅈ⋅k_{
#
# ⋅k_{b}             3      6  2⋅a⋅k_{b}               2      7  6⋅a⋅k_{b}
#        + 84.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 36.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 84.
# ──────────────────────────────────────────────────────────────────────────────
#   8                   7      2               6      3              5      4
# b} ⋅k_{e} + 36.0⋅k_{b} ⋅k_{e}  + 84.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 126.0⋅k_{b} ⋅k_{e}  -
#
#          2      7  4⋅a⋅k_{b}               2      7  2⋅a⋅k_{b}               2
# 0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 12.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 72.0⋅ⅈ⋅k_{b}
# ──────────────────────────────────────────────────────────────────────────────
#              4      5             3      6               2      7
# 126.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 84.0⋅k_{b} ⋅k_{e}  + 36.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 9.0⋅k_{b}⋅
#
#       7                  8  6⋅a⋅k_{b}                   8  4⋅a⋅k_{b}
# ⋅k_{e}  + 9.0⋅k_{b}⋅k_{e} ⋅ℯ          - 36.0⋅k_{b}⋅k_{e} ⋅ℯ          + 45.0⋅k_
# ──────────────────────────────────────────────────────────────────────────────
#      8          9         ⎛             8             7                     6
# k_{e}  - ⅈ⋅k_{e}  + k_{e}⋅⎝- 6.0⋅ⅈ⋅k_{b}  + 36.0⋅k_{b} ⋅k_{e} + 84.0⋅ⅈ⋅k_{b} ⋅
#
#          8  2⋅a⋅k_{b}          9  6⋅a⋅k_{b}              9  4⋅a⋅k_{b}
# {b}⋅k_{e} ⋅ℯ          - ⅈ⋅k_{e} ⋅ℯ          + 6.0⋅ⅈ⋅k_{e} ⋅ℯ          - 15.0⋅ⅈ
# ──────────────────────────────────────────────────────────────────────────────
#      2             5      3             3      5               2      6
# k_{e}  - 84.0⋅k_{b} ⋅k_{e}  - 84.0⋅k_{b} ⋅k_{e}  - 84.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 36.0
#
#       9  2⋅a⋅k_{b}               9⎞  6⋅a⋅k_{b}⎞               ⎛       6
# ⋅k_{e} ⋅ℯ          + 20.0⋅ⅈ⋅k_{e} ⎠⋅ℯ         ⎠ + 1.0⋅ⅈ⋅k_{e}⋅⎝- k_{b}  - 6.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             7              8⎞  2⋅a⋅k_{b}   ⎛         9              8
# ⋅k_{b}⋅k_{e}  + 6.0⋅ⅈ⋅k_{e} ⎠⋅ℯ          + ⎝3.0⋅k_{b}  + 9.0⋅ⅈ⋅k_{b} ⋅k_{e} +
#
#        5                   4      2               3      3             2
# ⅈ⋅k_{b} ⋅k_{e} + 15.0⋅k_{b} ⋅k_{e}  + 20.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 15.0⋅k_{b} ⋅k_{e}
# ──────────────────────────────────────────────────────────────────────────────
#           7      2               6      3             5      4               4
# 12.0⋅k_{b} ⋅k_{e}  + 60.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 30.0⋅k_{b} ⋅k_{e}  + 78.0⋅ⅈ⋅k_{b}
#
# 4                    5            6         ⎛             5             4
#   - 6.0⋅ⅈ⋅k_{b}⋅k_{e}  + 1.0⋅k_{e}  + k_{e}⋅⎝- 4.0⋅ⅈ⋅k_{b}  + 12.0⋅k_{b} ⋅k_{e
# ──────────────────────────────────────────────────────────────────────────────
#       5             3      6               2      7                   8
# ⋅k_{e}  - 84.0⋅k_{b} ⋅k_{e}  + 12.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 45.0⋅k_{b}⋅k_{e}  - 15.0
#
#                3      2            2      3                     4            5
# } + 8.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 8.0⋅k_{b} ⋅k_{e}  + 12.0⋅ⅈ⋅k_{b}⋅k_{e}  - 4.0⋅k_{e}
# ──────────────────────────────────────────────────────────────────────────────
#         9⎞  4⋅a⋅k_{b}   ⎛         9  6⋅a⋅k_{b}            9  2⋅a⋅k_{b}
# ⋅ⅈ⋅k_{e} ⎠⋅ℯ          + ⎝1.0⋅k_{b} ⋅ℯ          - 3.0⋅k_{b} ⋅ℯ          - 9.0⋅ⅈ
#
# ⎞  2⋅a⋅k_{b}   ⎛       6  4⋅a⋅k_{b}            6              5        4⋅a⋅k_{
# ⎠⋅ℯ          + ⎝- k_{b} ⋅ℯ          + 2.0⋅k_{b}  + 6.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#       8        6⋅a⋅k_{b}              8        4⋅a⋅k_{b}              8
# ⋅k_{b} ⋅k_{e}⋅ℯ          - 6.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 9.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅
#
# b}              5        2⋅a⋅k_{b}             4      2  4⋅a⋅k_{b}
#    + 4.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 15.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 12.0⋅k_{b
# ──────────────────────────────────────────────────────────────────────────────
#  2⋅a⋅k_{b}               8                   7      2  6⋅a⋅k_{b}             7
# ℯ          + 12.0⋅ⅈ⋅k_{b} ⋅k_{e} - 36.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 36.0⋅k_{b}
#
#  4      2  2⋅a⋅k_{b}             4      2               3      3  4⋅a⋅k_{b}
# } ⋅k_{e} ⋅ℯ          + 10.0⋅k_{b} ⋅k_{e}  - 20.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          -
# ──────────────────────────────────────────────────────────────────────────────
#       2  4⋅a⋅k_{b}             7      2  2⋅a⋅k_{b}               6      3  6⋅a
# ⋅k_{e} ⋅ℯ          - 12.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 84.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ
#
#            3      3  2⋅a⋅k_{b}             2      4  4⋅a⋅k_{b}            2
# 8.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 15.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 8.0⋅k_{b} ⋅k_
# ──────────────────────────────────────────────────────────────────────────────
# ⋅k_{b}               6      3  4⋅a⋅k_{b}               6      3  2⋅a⋅k_{b}
#        + 84.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 60.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 5
#
#    4  2⋅a⋅k_{b}             2      4                    5  4⋅a⋅k_{b}
# {e} ⋅ℯ          + 14.0⋅k_{b} ⋅k_{e}  + 6.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          - 12.0⋅ⅈ⋅
# ──────────────────────────────────────────────────────────────────────────────
#            6      3              5      4  6⋅a⋅k_{b}             5      4  4⋅a
# 6.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 126.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 84.0⋅k_{b} ⋅k_{e} ⋅ℯ
#
#            5  2⋅a⋅k_{b}            6  4⋅a⋅k_{b}            6  2⋅a⋅k_{b}
# k_{b}⋅k_{e} ⋅ℯ          + 1.0⋅k_{e} ⋅ℯ          - 4.0⋅k_{e} ⋅ℯ          + 6.0⋅
# ──────────────────────────────────────────────────────────────────────────────
# ⋅k_{b}             5      4  2⋅a⋅k_{b}                4      5  6⋅a⋅k_{b}
#        + 30.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 126.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 78
#
#      6⎞  4⋅a⋅k_{b}⎞ ⎛       8              7                   6      2
# k_{e} ⎠⋅ℯ         ⎠⋅⎝- k_{b}  - 8.0⋅ⅈ⋅k_{b} ⋅k_{e} + 28.0⋅k_{b} ⋅k_{e}  + 56.0
# ──────────────────────────────────────────────────────────────────────────────
#           4      5  2⋅a⋅k_{b}               4      5             3      6  6⋅a
# .0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 96.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 84.0⋅k_{b} ⋅k_{e} ⋅ℯ
#
#         5      3             4      4               3      5             2
# ⋅ⅈ⋅k_{b} ⋅k_{e}  - 70.0⋅k_{b} ⋅k_{e}  - 56.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 28.0⋅k_{b} ⋅k_{
# ──────────────────────────────────────────────────────────────────────────────
# ⋅k_{b}             3      6  4⋅a⋅k_{b}             3      6  2⋅a⋅k_{b}
#        + 84.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 84.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 36.0⋅
#
#   6                    7        8   ⎛           8               7
# e}  + 8.0⋅ⅈ⋅k_{b}⋅k_{e}  - k_{e}  + ⎝- 2.0⋅k_{b}  - 16.0⋅ⅈ⋅k_{b} ⋅k_{e} + 48.0
# ──────────────────────────────────────────────────────────────────────────────
#        2      7  6⋅a⋅k_{b}               2      7  4⋅a⋅k_{b}               2
# ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 84.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 12.0⋅ⅈ⋅k_{b} ⋅k
#
#       6      2               5      3             4      4               3
# ⋅k_{b} ⋅k_{e}  + 64.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 20.0⋅k_{b} ⋅k_{e}  + 48.0⋅ⅈ⋅k_{b} ⋅k_{
# ──────────────────────────────────────────────────────────────────────────────
#     7  2⋅a⋅k_{b}               2      7                  8  6⋅a⋅k_{b}
# _{e} ⋅ℯ          + 72.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 9.0⋅k_{b}⋅k_{e} ⋅ℯ          - 36.0⋅k
#
#   5             2      6                     7            8⎞  2⋅a⋅k_{b}   ⎛
# e}  - 64.0⋅k_{b} ⋅k_{e}  - 32.0⋅ⅈ⋅k_{b}⋅k_{e}  + 6.0⋅k_{e} ⎠⋅ℯ          + ⎝1.0
# ──────────────────────────────────────────────────────────────────────────────
#           8  4⋅a⋅k_{b}                   8  2⋅a⋅k_{b}          9  6⋅a⋅k_{b}
# _{b}⋅k_{e} ⋅ℯ          + 45.0⋅k_{b}⋅k_{e} ⋅ℯ          - ⅈ⋅k_{e} ⋅ℯ          +
#
#       8              7                   6      2               5      3
# ⋅k_{b}  - 8.0⋅ⅈ⋅k_{b} ⋅k_{e} + 36.0⋅k_{b} ⋅k_{e}  + 24.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 54.
# ──────────────────────────────────────────────────────────────────────────────
#            9  4⋅a⋅k_{b}               9  2⋅a⋅k_{b}               9⎞  6⋅a⋅k_{b}
# 6.0⋅ⅈ⋅k_{e} ⋅ℯ          - 15.0⋅ⅈ⋅k_{e} ⋅ℯ          + 20.0⋅ⅈ⋅k_{e} ⎠⋅ℯ
#
#        4      4               3      5            2      6
# 0⋅k_{b} ⋅k_{e}  + 72.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 4.0⋅k_{b} ⋅k_{e}  + 40.0⋅ⅈ⋅k_{b}⋅k_{e
# ──────────────────────────────────────────────────────────────────────────────
# ⎞
# ⎠
#
#  7             8⎞  4⋅a⋅k_{b}   ⎛       8  6⋅a⋅k_{b}            8  4⋅a⋅k_{b}
# }  - 15.0⋅k_{e} ⎠⋅ℯ          + ⎝- k_{b} ⋅ℯ          - 2.0⋅k_{b} ⋅ℯ          +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          8  2⋅a⋅k_{b}            8              7        6⋅a⋅k_{b}
# 1.0⋅k_{b} ⋅ℯ          + 4.0⋅k_{b}  + 8.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 16.0⋅ⅈ⋅k_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    7        4⋅a⋅k_{b}              7        2⋅a⋅k_{b}             6      2  6⋅
# {b} ⋅k_{e}⋅ℯ          + 8.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 28.0⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# a⋅k_{b}             6      2  4⋅a⋅k_{b}             6      2  2⋅a⋅k_{b}
#         + 48.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 36.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 32.0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       6      2               5      3  6⋅a⋅k_{b}               5      3  4⋅a⋅k
# ⋅k_{b} ⋅k_{e}  - 56.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 64.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _{b}               5      3  2⋅a⋅k_{b}             4      4  6⋅a⋅k_{b}
#      - 24.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 70.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 20.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      4      4  4⋅a⋅k_{b}             4      4  2⋅a⋅k_{b}             4      4
# k_{b} ⋅k_{e} ⋅ℯ          + 54.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 72.0⋅k_{b} ⋅k_{e}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               3      5  6⋅a⋅k_{b}               3      5  4⋅a⋅k_{b}
# + 56.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 48.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 72.0⋅ⅈ⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     3      5  2⋅a⋅k_{b}             2      6  6⋅a⋅k_{b}             2      6
# _{b} ⋅k_{e} ⋅ℯ          + 28.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 64.0⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 4⋅a⋅k_{b}            2      6  2⋅a⋅k_{b}             2      6
#           + 4.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 64.0⋅k_{b} ⋅k_{e}  - 8.0⋅ⅈ⋅k_{b}⋅k_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    7  6⋅a⋅k_{b}                     7  4⋅a⋅k_{b}                     7  2⋅a⋅k_
# {e} ⋅ℯ          + 32.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          - 40.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# {b}        8  6⋅a⋅k_{b}            8  4⋅a⋅k_{b}             8  2⋅a⋅k_{b}
#     - k_{e} ⋅ℯ          + 6.0⋅k_{e} ⋅ℯ          - 15.0⋅k_{e} ⋅ℯ          + 20.
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        8⎞  6⋅a⋅k_{b}⎞⎞
# 0⋅k_{e} ⎠⋅ℯ         ⎠⎠
# ──────────────────────

# %%
cbd = Am1[1,0]*ced + 0 + Am1[1,2]*1j*ke*ced + 0; simplify(cbd)
# Out:
#
#                                                                          c_{ed
# ──────────────────────────────────────────────────────────────────────────────
#        6  8⋅a⋅k_{b}            6  4⋅a⋅k_{b}        6              5        8⋅a
# - k_{b} ⋅ℯ          + 2.0⋅k_{b} ⋅ℯ          - k_{b}  + 6.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ
#
#         ⎛           5  6⋅a⋅k_{b}              5  4⋅a⋅k_{b}              5  2⋅a
# }⋅k_{e}⋅⎝2.0⋅ⅈ⋅k_{b} ⋅ℯ          + 2.0⋅ⅈ⋅k_{b} ⋅ℯ          - 2.0⋅ⅈ⋅k_{b} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
# ⋅k_{b}              5        6⋅a⋅k_{b}              5        2⋅a⋅k_{b}
#        + 4.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          - 4.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          - 6.0⋅ⅈ
#
# ⋅k_{b}              5             4        6⋅a⋅k_{b}             4        4⋅a⋅
#        - 2.0⋅ⅈ⋅k_{b}  + 10.0⋅k_{b} ⋅k_{e}⋅ℯ          + 10.0⋅k_{b} ⋅k_{e}⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#       5                   4      2  8⋅a⋅k_{b}             4      2  6⋅a⋅k_{b}
# ⋅k_{b} ⋅k_{e} + 15.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 12.0⋅k_{b} ⋅k_{e} ⋅ℯ
#
# k_{b}            4        2⋅a⋅k_{b}            4                     3      2
#       + 6.0⋅k_{b} ⋅k_{e}⋅ℯ          + 6.0⋅k_{b} ⋅k_{e} - 20.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅
# ──────────────────────────────────────────────────────────────────────────────
#             4      2  4⋅a⋅k_{b}             4      2  2⋅a⋅k_{b}             4
# + 10.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 12.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 15.0⋅k_{b} ⋅
#
#  6⋅a⋅k_{b}               3      2  4⋅a⋅k_{b}              3      2  2⋅a⋅k_{b}
# ℯ          - 12.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 4.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#      2               3      3  8⋅a⋅k_{b}              3      3  6⋅a⋅k_{b}
# k_{e}  - 20.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 8.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 8.
#
#              3      2             2      3  6⋅a⋅k_{b}            2      3  4⋅a
# + 4.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 20.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 4.0⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#          3      3  2⋅a⋅k_{b}               3      3             2      4  8⋅a⋅
# 0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 20.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 15.0⋅k_{b} ⋅k_{e} ⋅ℯ
#
# ⋅k_{b}             2      3  2⋅a⋅k_{b}            2      3
#        + 12.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 4.0⋅k_{b} ⋅k_{e}  + 10.0⋅ⅈ⋅k_{b}⋅k_{e
# ──────────────────────────────────────────────────────────────────────────────
# k_{b}            2      4  6⋅a⋅k_{b}             2      4  4⋅a⋅k_{b}
#       + 8.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 14.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 8.0⋅k_{
#
#  4  6⋅a⋅k_{b}                     4  4⋅a⋅k_{b}                    4  2⋅a⋅k_{b}
# } ⋅ℯ          - 14.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          - 2.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#   2      4  2⋅a⋅k_{b}             2      4                    5  8⋅a⋅k_{b}
# b} ⋅k_{e} ⋅ℯ          - 15.0⋅k_{b} ⋅k_{e}  + 6.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          - 1
#
#                     4            5  6⋅a⋅k_{b}            5  4⋅a⋅k_{b}
#  + 6.0⋅ⅈ⋅k_{b}⋅k_{e}  + 2.0⋅k_{e} ⋅ℯ          - 6.0⋅k_{e} ⋅ℯ          + 6.0⋅k_
# ──────────────────────────────────────────────────────────────────────────────
#                  5  6⋅a⋅k_{b}                     5  2⋅a⋅k_{b}
# 2.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          + 12.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          - 6.0⋅ⅈ⋅k_{b}⋅k
#
#    5  2⋅a⋅k_{b}            5⎞  2⋅a⋅k_{b}
# {e} ⋅ℯ          - 2.0⋅k_{e} ⎠⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#     5            6  8⋅a⋅k_{b}            6  6⋅a⋅k_{b}            6  4⋅a⋅k_{b}
# _{e}  + 1.0⋅k_{e} ⋅ℯ          - 4.0⋅k_{e} ⋅ℯ          + 6.0⋅k_{e} ⋅ℯ
#
#
#
# ────────────────────────────────────
#            6  2⋅a⋅k_{b}            6
# - 4.0⋅k_{e} ⋅ℯ          + 1.0⋅k_{e}

# %%
cbc = Am1[2,0]*ced + 0 + Am1[2,2]*1j*ke*ced + 0; simplify(cbc)
# Out:
#
#                                                                              c
# ──────────────────────────────────────────────────────────────────────────────
#          6  8⋅a⋅k_{b}            6  4⋅a⋅k_{b}            6              5
# 1.0⋅k_{b} ⋅ℯ          - 2.0⋅k_{b} ⋅ℯ          + 1.0⋅k_{b}  - 6.0⋅ⅈ⋅k_{b} ⋅k_{e
#
#             ⎛             5  6⋅a⋅k_{b}              5  4⋅a⋅k_{b}
# _{ed}⋅k_{e}⋅⎝- 2.0⋅ⅈ⋅k_{b} ⋅ℯ          - 2.0⋅ⅈ⋅k_{b} ⋅ℯ          + 2.0⋅ⅈ⋅k_{b}
# ──────────────────────────────────────────────────────────────────────────────
#    8⋅a⋅k_{b}              5        6⋅a⋅k_{b}              5        2⋅a⋅k_{b}
# }⋅ℯ          - 4.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          + 4.0⋅ⅈ⋅k_{b} ⋅k_{e}⋅ℯ          +
#
# 5  2⋅a⋅k_{b}              5            4        6⋅a⋅k_{b}            4
#  ⋅ℯ          + 2.0⋅ⅈ⋅k_{b}  - 6.0⋅k_{b} ⋅k_{e}⋅ℯ          - 6.0⋅k_{b} ⋅k_{e}⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#             5                   4      2  8⋅a⋅k_{b}             4      2  6⋅a⋅
#  6.0⋅ⅈ⋅k_{b} ⋅k_{e} - 15.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 12.0⋅k_{b} ⋅k_{e} ⋅ℯ
#
# 4⋅a⋅k_{b}             4        2⋅a⋅k_{b}             4                    3
#           - 10.0⋅k_{b} ⋅k_{e}⋅ℯ          - 10.0⋅k_{b} ⋅k_{e} + 4.0⋅ⅈ⋅k_{b} ⋅k_
# ──────────────────────────────────────────────────────────────────────────────
# k_{b}             4      2  4⋅a⋅k_{b}             4      2  2⋅a⋅k_{b}
#       - 10.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 12.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 15.0⋅k
#
#    2  6⋅a⋅k_{b}              3      2  4⋅a⋅k_{b}               3      2  2⋅a⋅k
# {e} ⋅ℯ          - 4.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 12.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#     4      2               3      3  8⋅a⋅k_{b}              3      3  6⋅a⋅k_{b
# _{b} ⋅k_{e}  + 20.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          + 8.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ
#
# _{b}               3      2            2      3  6⋅a⋅k_{b}             2
#      - 20.0⋅ⅈ⋅k_{b} ⋅k_{e}  - 4.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 12.0⋅k_{b} ⋅k_{e}
# ──────────────────────────────────────────────────────────────────────────────
# }              3      3  2⋅a⋅k_{b}               3      3             2      4
#   - 8.0⋅ⅈ⋅k_{b} ⋅k_{e} ⋅ℯ          - 20.0⋅ⅈ⋅k_{b} ⋅k_{e}  + 15.0⋅k_{b} ⋅k_{e}
#
# 3  4⋅a⋅k_{b}            2      3  2⋅a⋅k_{b}             2      3
#  ⋅ℯ          - 4.0⋅k_{b} ⋅k_{e} ⋅ℯ          + 20.0⋅k_{b} ⋅k_{e}  + 6.0⋅ⅈ⋅k_{b}
# ──────────────────────────────────────────────────────────────────────────────
#   8⋅a⋅k_{b}            2      4  6⋅a⋅k_{b}             2      4  4⋅a⋅k_{b}
# ⋅ℯ          - 8.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 14.0⋅k_{b} ⋅k_{e} ⋅ℯ          - 8
#
#       4  6⋅a⋅k_{b}                    4  4⋅a⋅k_{b}                     4  2⋅a⋅
# ⋅k_{e} ⋅ℯ          - 2.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          - 14.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#         2      4  2⋅a⋅k_{b}             2      4                    5  8⋅a⋅k_{
# .0⋅k_{b} ⋅k_{e} ⋅ℯ          + 15.0⋅k_{b} ⋅k_{e}  - 6.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ
#
# k_{b}                     4            5  6⋅a⋅k_{b}            5  4⋅a⋅k_{b}
#       + 10.0⋅ⅈ⋅k_{b}⋅k_{e}  + 2.0⋅k_{e} ⋅ℯ          - 6.0⋅k_{e} ⋅ℯ          +
# ──────────────────────────────────────────────────────────────────────────────
# b}                     5  6⋅a⋅k_{b}                     5  2⋅a⋅k_{b}
#    + 12.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          - 12.0⋅ⅈ⋅k_{b}⋅k_{e} ⋅ℯ          + 6.0⋅ⅈ⋅k
#
#          5  2⋅a⋅k_{b}            5⎞
# 6.0⋅k_{e} ⋅ℯ          - 2.0⋅k_{e} ⎠
# ──────────────────────────────────────────────────────────────────────────────
#           5        6  8⋅a⋅k_{b}            6  6⋅a⋅k_{b}            6  4⋅a⋅k_{b
# _{b}⋅k_{e}  - k_{e} ⋅ℯ          + 4.0⋅k_{e} ⋅ℯ          - 6.0⋅k_{e} ⋅ℯ
#
#
#
# ──────────────────────────────────
# }            6  2⋅a⋅k_{b}        6
#   + 4.0⋅k_{e} ⋅ℯ          - k_{e}

# %%
cdd = Am1[3,0]*ced + 0 + Am1[3,2]*1j*ke*ced + 0; simplify(cdd)
# Out:
#                                                    a⋅(k_{b} - ⅈ⋅k_{e})
#                          4.0⋅ⅈ⋅c_{ed}⋅k_{b}⋅k_{e}⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#          2                            2   ⎛       2
# 1.0⋅k_{b}  + 2.0⋅ⅈ⋅k_{b}⋅k_{e} - k_{e}  + ⎝- k_{b}  + 2.0⋅ⅈ⋅k_{b}⋅k_{e} + 1.0⋅
#
#
#
# ──────────────────
#      2⎞  2⋅a⋅k_{b}
# k_{e} ⎠⋅ℯ

# %% [markdown]
# ## Densidade de probabilidade
# Assumiremos $c_{ed}\in\mathbb{R}$. Usando as expressões obtidas acima para os coeficientes das funções de onda, obteremos à esquerda da barreira:
# \begin{align}
# |\Xi_{e}|^{2} & = \Xi_{e}\Xi_{e}^{*} \\
# & = \left(c_{ed}e^{ik_{e}x}+c_{ee}e^{-ik_{e}x}\right)\left(c_{ed}^{*}e^{-ik_{e}x}+c_{ee}^{*}e^{ik_{e}x}\right) \\
# & = |c_{ed}|^{2} + c_{ed}c_{ee}^{*}e^{2ik_{e}x} + c_{ee}c_{ed}^{*}e^{-ik_{e}x} + |c_{ee}|^{2} \\
# & = |c_{ed}|^{2} + |c_{ee}|^{2} + 2\Re\left(c_{ed}c_{ee}^{*}e^{2ik_{e}x}\right) \\
# & = c_{ed}^{2} + |c_{ee}|^{2} + 2c_{ed}\left(\Re(c_{ee}^{*})\Re\left(e^{2ik_{e}x}\right)-\Im(c_{ee}^{*})\Im\left(e^{2ik_{e}x}\right)\right) \\
# & = c_{ed}^{2} + |c_{ee}|^{2} + 2c_{ed}\left(\Re(c_{ee})\cos(2k_{e}x)+\Im(c_{ee})\sin(2k_{e}x)\right).
# \end{align}
# Na barreira
# \begin{align}
# |\Xi_{b}|^{2} & = \Xi_{b}\Xi_{b}^{*} \\
# & = \left(c_{bd}e^{-k_{b}x}+c_{bc}e^{k_{b}x}\right)\left(c_{bd}^{*}e^{-k_{b}x}+c_{bc}^{*}e^{k_{b}x}\right) \\
# & = |c_{bd}|^{2}e^{-2k_{b}x} + c_{bd}c_{bc}^{*} + c_{bd}^{*}c_{bc} + |c_{bc}|^{2}e^{2k_{b}x} \\
# & = |c_{bd}|^{2}e^{-2k_{b}x} + |c_{bc}|^{2}e^{2k_{b}x} + 2\Re(c_{bd}c_{bc}^{*}) \\
# & = |c_{bd}|^{2}e^{-2k_{b}x} + |c_{bc}|^{2}e^{2k_{b}x} + 2(\Re(c_{bd})\Re(c_{bc}^{*})-\Im(c_{bd})\Im(c_{bc}^{*})) \\
# & = |c_{bd}|^{2}e^{-2k_{b}x} + |c_{bc}|^{2}e^{2k_{b}x} + 2(\Re(c_{bd})\Re(c_{bc})+\Im(c_{bd})\Im(c_{bc})).
# \end{align}
# À direita da barreira
# \begin{align}
# |\Xi_{d}|^{2} & = \Xi_{d}\Xi_{d}^{*} = c_{dd}e^{ik_{e}x}c_{dd}^{*}e^{-ik_{e}x} = |c_{dd}|^{2}.
# \end{align}
#
# Essas densidades de probabilidade estão mostradas na figura abaixo.
#
# OBS. O limite de $a$ "muito" grande fornece o mesmo comportamento do potencial degrau.

# %%
from ipywidgets import interactive
import matplotlib
from matplotlib import pyplot as plt
import math
import numpy as np

# %%
def E_lt_U0(E,a):
    matplotlib.rcParams.update({'font.size':12}); 
    plt.figure(figsize = (8,3), dpi = 100)
    U0 = 0.5; m = 1; ke = math.sqrt(2*m*E); 
    kb = math.sqrt(U0/E-1)*ke; ced = 0.5
    den = -1j*kb**2*math.exp(2*a*kb)*math.sin(a*ke)\
    - kb**2*math.exp(2*a*kb)*math.cos(a*ke) + 1j*kb**2*math.sin(a*ke)\
    + kb**2*math.cos(a*ke) - 2*kb*ke*math.exp(2*a*kb)*math.sin(a*ke)\
    + 2*1j*kb*ke*math.exp(2*a*kb)*math.cos(a*ke) - 2*kb*ke*math.sin(a*ke)\
    + 2*1j*kb*ke*math.cos(a*ke) + 1j*ke**2*math.exp(2*a*kb)*math.sin(a*ke)\
    + ke**2*math.exp(2*a*kb)*math.cos(a*ke) - 1j*ke**2*math.sin(a*ke)\
    - ke**2*math.cos(a*ke) 
    cee = ced*(1j*kb**2*math.exp(2*a*kb)*math.sin(a*ke)\
               + kb**2*math.exp(2*a*kb)*math.cos(a*ke)\
               - 1j*kb**2*math.sin(a*ke) - kb**2*math.cos(a*ke)\
               + 1j*ke**2*math.exp(2*a*kb)*math.sin(a*ke)\
               + ke**2*math.exp(2*a*kb)*math.cos(a*ke)\
               - 1j*ke**2*math.sin(a*ke) - ke**2*math.cos(a*ke))
    cee /= den
    cbc = 2*ced*ke*(-kb*math.sin(a*ke) + 1j*kb*math.cos(a*ke)\
                    - 1j*ke*math.sin(a*ke) - ke*math.cos(a*ke))
    cbc /= den
    cbd = 2*1j*ced*ke*(kb*(math.cos(a*ke)+1j*math.sin(a*ke))\
                       + ke*(math.sin(a*ke)\
                             - 1j*math.cos(a*ke)))*math.exp(2*a*kb)
    cbd /= den
    cdd = 4*1j*ced*kb*ke*math.exp(a*kb)
    cdd /= den 
    N = 1000; xmin = -5*math.pi; xmax = -xmin; dx = (xmax-xmin)/N;
    x = np.zeros(N); y = np.zeros(N)
    for j in range(0,N):
        x[j] = xmin + j*dx
        if x[j] < 0:
            y[j] = ced**2 + (cee.real)**2 + (cee.imag)**2\
            + 2*ced*((cee.real)*math.cos(2*ke*x[j])\
                     +(cee.imag)*math.sin(2*ke*x[j]))
        elif x[j] > 0 and x[j] < a:
            y[j] = ((cbd.real)**2+(cbd.imag)**2)*math.exp(-2*kb*x[j])\
            +((cbc.real)**2+(cbc.imag)**2)*math.exp(2*kb*x[j])\
            +2*((cbd.real)*(cbc.real)+(cbd.imag)*(cbc.imag))
        elif x[j] > a:
            y[j] = (cdd.real)**2+(cdd.imag)**2
    plt.annotate(r'$E=$'+str(E)[:5], xy=(xmax-8,0.8), 
                 xytext=(xmax-8,0.8), fontsize=12)
    plt.plot(x,y); plt.xlabel(r'$x$',fontsize=10); 
    plt.ylabel(r'$|\Xi|^{2}$',fontsize=15)
    plt.annotate(r'$a=$'+str(a)[:4], xy=(a,0.02), 
                 xytext=(a,0.02), fontsize=12)
    plt.xlim(xmin,xmax); plt.ylim(0.0,1.01)
    plt.annotate("", xy=(0,0), xytext=(0,U0), 
                 arrowprops=dict(arrowstyle="-"))
    plt.annotate("", xy=(a,0), xytext=(a,U0), 
                 arrowprops=dict(arrowstyle="-"))
    plt.annotate("", xy=(0-0.08,U0-0.005), xytext=(a+0.08,U0-0.005), 
                 arrowprops=dict(arrowstyle="-"))
    plt.savefig('z10_psiEmU.png',format = 'png', dpi = 100)
    plt.show()
interactive(E_lt_U0, E=(0+10**-3,0.5-10**-3,0.01), a=(0.1,10,0.5))
# Out:
# interactive(children=(FloatSlider(value=0.241, description='E', max=0.499, min=0.001, step=0.01), FloatSlider(…

# %% [markdown]
# ## Tunelamento quântico
# No caso da barreira de potencial, como quantons podem ser refletidos tanto em $x=0$ quanto em $x=a$, iniciaremos calculando o coeficiente de transmissão, que é dado por:
# \begin{equation}
# T:=\frac{|c_{dd}|^{2}}{|c_{ed}|^{2}},
# \end{equation}
# uma vez que a velocidade é a mesma, $\omega/k_{e}$, nas regiões $x<0$ e $x>a$. Simplificando obtemos
# \begin{align}
# c_{dd} & = \frac{-ic_{ed}4k_{e}k_{b}e^{k_{b}a}e^{-ik_{e}a}}{2k_{b}(k_{b}-ik_{e})e^{2k_{b}a}-(k_{b}+ik_{e})(k_{b}+ik_{e}+(k_{b}-ik_{e})e^{2k_{b}a})} \\
# & = \frac{-ic_{ed}4k_{e}k_{b}e^{k_{b}a}e^{-ik_{e}a}} {2(k_{b}^{2}-ik_{b}k_{e})e^{2k_{b}a}-k_{b}^{2}-2ik_{b}k_{e}+k_{e}^{2}-(k_{b}^{2}+k_{e}^{2})e^{2k_{b}a}} \\
# & = \frac{-ic_{ed}4k_{e}k_{b}e^{k_{b}a}e^{-ik_{e}a}} {(2k_{b}^{2}-k_{b}^{2}-k_{e}^{2})e^{2k_{b}a}-k_{b}^{2}+k_{e}^{2}-2ik_{b}k_{e}(e^{2k_{b}a}+1)}\frac{e^{-k_{b}a}}{e^{-k_{b}a}} \\
# & = \frac{-ic_{ed}4k_{e}k_{b}e^{-ik_{e}a}} {(k_{b}^{2}-k_{e}^{2})e^{k_{b}a}-(k_{b}^{2}-k_{e}^{2})e^{-k_{b}a}-2ik_{b}k_{e}(e^{k_{b}a}+e^{-k_{b}a})}\frac{1/4k_{b}k_{e}}{1/4k_{b}k_{e}} \\
# & = \frac{-ic_{ed}e^{-ik_{e}a}} {\frac{k_{b}^{2}-k_{e}^{2}}{2k_{b}k_{e}}\frac{e^{k_{b}a}-e^{-k_{b}a}}{2}-i\frac{e^{k_{b}a}+e^{-k_{b}a}}{2}} \\
# & = \frac{-ie^{-ik_{e}a}} {\frac{k_{b}^{2}-k_{e}^{2}}{2k_{b}k_{e}}\sinh(k_{b}a)-i\cosh(k_{b}a)}c_{ed}.
# \end{align}

# %% [markdown]
# Segue assim que
# \begin{align}
# T & = \frac{1} {\frac{(k_{b}^{2}-k_{e}^{2})^{2}}{4k_{b}^{2}k_{e}^{2}}\sinh^{2}(k_{b}a)+\cosh^{2}(k_{b}a)} \\
# & = \frac{4k_{b}^{2}k_{e}^{2}} {(k_{b}^{4}+k_{e}^{4}-2k_{b}^{2}k_{e}^{2})\sinh^{2}(k_{b}a)+4k_{b}^{2}k_{e}^{2}\cosh^{2}(k_{b}a)} \\
# & = \frac{4k_{b}^{2}k_{e}^{2}} {(k_{b}^{4}+k_{e}^{4}+2k_{b}^{2}k_{e}^{2})\sinh^{2}(k_{b}a)+4k_{b}^{2}k_{e}^{2}(\cosh^{2}(k_{b}a)-\sinh^{2}(k_{b}a))} \\
# & = \frac{1} {\frac{(k_{b}^{2}+k_{e}^{2})^{2}}{4k_{b}^{2}k_{e}^{2}}\sinh^{2}(k_{b}a)+1}.
# \end{align}
# Como
# \begin{align}
# & \frac{(k_{b}^{2}+k_{e}^{2})^{2}}{k_{b}^{2}k_{e}^{2}} = \frac{(2m(U_{0}-E)+2mE)^{2}}{2m(U_{0}-E)2mE} = \frac{U_{0}^{2}}{E(U_{0}-E)} = \frac{1}{\frac{E}{U_{0}}\left(1-\frac{E}{U_{0}}\right)}.
# \end{align}
# obteremos, finalmente, que
# \begin{equation}
# T = \left(\frac{\sinh^{2}\left(ak_{e}\sqrt{\frac{U_{0}}{E}-1}\right)}{4\frac{E}{U_{0}}\left(1-\frac{E}{U_{0}}\right)}+1\right)^{-1}.
# \end{equation}

# %%
def EltU0(a):
    matplotlib.rcParams.update({'font.size':12}); 
    plt.figure(figsize = (4,4), dpi = 100)
    U0 = 1; m = 1; hbb = 1
    x = np.arange(0.01,0.999,0.005); 
    ke = np.sqrt(2*m*x)/hbb; kb = np.sqrt((U0/x)-1)*ke
    T = 1/(1+((np.sinh(kb*a)**2)*((kb**2+ke**2)**2/(4*kb**2*ke**2)))); 
    R = 1-T
    plt.plot(x,R); plt.plot(x,T); 
    plt.xlim(0,1); plt.ylim(-0.01,1.05)
    plt.xlabel(r'$E/U_{0}$'); 
    plt.legend((r'$R$',r'$T$'),loc=(1.01,0.5))
    plt.annotate(r'$a=$'+str(a)[:5], xy=(0.8,0.9), 
                 xytext=(1.01,0.9), fontsize=12)
    plt.show()
interactive(EltU0, a=(10**-10,3,0.1))
# Out:
# interactive(children=(FloatSlider(value=1.4000000001000001, description='a', max=3.0, min=1e-10), Output()), _…

# %% [markdown]
# ## Aplicações
# Vemos assim que, ao contrário do regime clássico, no regime quântico um quanton pode, mesmo tendo energia menor do que a altura da barreira, passar para o outro lado. Esse fenômeno é o chamado de __tunelamento quântico__. O tunelamendo quântico, assim como vários outros fenômenos quânticos, podem ser pensados como sendo cosequência do aspecto ondulatório dos quantons. No caso do tunelamento quântico, existe um fenômeno ondulatório clássico análogo, que é a chamada __reflexão interna total frustrada__.
#
# O tunelamento quântico possui muitas aplicações físicas e tecnológicas: O funcionamento do _olfato_ envolve, em parte, o tunelamento quântico (https://www.ted.com/talks/luca_turin_the_science_of_scent?utm_campaign=tedspread&utm_medium=referral&utm_source=tedcomshare), que tem associado um _espectroscópio_ para medida de frequências de vibrações moleculares. Esse fenômeno também tem outras aplicações tecnológicas importantes tais como o _microscópio de varredura por tunelamento_ (https://www.nobelprize.org/prizes/physics/1986/rohrer/lecture/), o _diodo túnel_ (https://www.nobelprize.org/prizes/physics/1973/esaki/lecture/), as _juncões Josephson_ (https://www.nobelprize.org/prizes/physics/1973/josephson/lecture/), os _relógios atômicos_ (https://cienciahoje.org.br/coluna/se-nao-fosse-o-relogio-atomico/), (https://www.nobelprize.org/uploads/2018/06/hansch-lecture.pdf), etc.

# %% [markdown]
# ---
# # Exercícios
#
# $1.$ Dadas as definições $\sinh(x):=(e^{x}-e^{-x})/2$ e $\cosh(x):=(e^{x}+e^{-x})/2$, verifique que $\cosh^{2}(x)-\sinh^{2}(x)=1$.
#
# $2.$ Uma camada de óxido, em um dispositivo semicondutor, forma uma barreira de $0,6\text{ nm}$ de largura e $9\text{ eV}$ de altura. Para elétrons acelerados com uma ddp de $4\text{ V}$, qual é a fração deles que consegue atravessar a barreira? Qual deveria ser a ddp de aceleração para que o valor de $T$ seja o dobro desse valor?
#
# $3.$ Faça todos os cálculos necessários para obter o coeficiente de trasmissão para $E>U_{0}$, sob as mesmas condições iniciais usadas nas notas de aula para o caso $E<U_{0}$. Faça um gráfico de $T$ e $R$ versus $E/U_{0}$.
