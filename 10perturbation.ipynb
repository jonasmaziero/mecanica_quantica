# %% [markdown]
# UFSM: 2018/1; Notas de aula: Mecânica Quântica; Autor: Jonas Maziero

# %% [markdown]
# # Teoria de perturbação
# O objetivo de teoria de perturbação é construir soluções aproximadas (estáticas e/ou dinâmicas) a partir das soluções analíticas obtidas em casos particulares.

# %% [markdown]
# ## Teoria de perturbação independente do tempo

# %% [markdown]
# ## Teoria de perturbação dependente do tempo
